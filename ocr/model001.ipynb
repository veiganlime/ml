# %% [markdown]
# ## Initialize

# %%
import os 
import cv2
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt

import keras
from keras.callbacks import TensorBoard

# %matplotlib inline

# %% [markdown]
# ## Download the MNIST dataset

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %% [markdown]
# ## Train and save the model

# %%
log_path = "logs/"

tensorboard = TensorBoard(log_dir = log_path, histogram_freq=0, write_graph=True)
callbacks_list = [tensorboard]

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, epochs=30, callbacks=callbacks_list)

model.save('model001_epoch30.h5')

# %% [markdown]
# ## Print the parameters of the model

# %%
model = tf.keras.models.load_model('model001_epoch30.h5')

loss, accuracy = model.evaluate(x_test, y_test)

print(loss)
print(accuracy)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - accuracy: 0.9706 - loss: 0.1954
# 0.17314815521240234
# 0.9757000207901001

# %%
prefix = 1 

while os.path.isfile(f"images/image{prefix}.png"):
    try:
        img = cv2.imread(f"images/image{prefix}.png")[:,:,0]
        img = np.invert(np.array([img]))
        prediction = model.predict(img)
        print(f"This image is {np.argmax(prediction)}")
        plt.imshow(img[0], cmap=plt.cm.binary)
        plt.show()
    except:
        print("Error!")
    finally:
        prefix += 1

# %%
results = model.evaluate(x_test, y_test)
print(print("\nLoss: %.2f%%, Accuracy: %.2f%%" % (results[0], results[1])))

# %% [markdown]
# ## Launch TensorBoard

# %%
print(os.getcwd())

# %%
# %%bash
# tensorboard --logdir=/Users/lime/src/ml/ocr/logs/
